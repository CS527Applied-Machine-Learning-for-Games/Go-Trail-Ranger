# %% [markdown]
# ***Week 10 Graph with distribution of Subway Surfers data***

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Left Move', 'Right Move', 'Jump Move', 'Roll Move'
sizes = [24.61, 30.73, 28.83, 10.17]
explode = (0.1, 0.1, 0, 0)  # only "explode" the 1st and 2nd slice

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Subway Surfers', 'Go! Trail Rangers'
sizes = [76.5, 23.5]
explode = (0.1, 0.1, 0, 0)  # only "explode" the 1st and 2nd slice

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=None, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.style.use('classic')

# %% [markdown]
# ***Variant of Transfer Learning - Results***

# %%
# Batch size vs loss value maintaining 32 iterations

plt.plot([32,64,96,128], [0.6887,0.6467,0.7024,0.7344])

# %%
# Iteration size vs loss value 
plt.plot([32,64,96,128], [0.6467,0.6888, 0.6894,0.6786])

# %%
#Loss function vs epochs

plt.title("TL Merged Network - Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")

plt.plot([1,3,5,7,11,13,15,17,19,21,23,25,27,31,33,35,37,39,41,43,45,47,51,53,55,57,59,61,63,65,67,69,71,73,75,77,79],
         [0.7319,0.6530,0.7950,0.9615,1.2356,0.7295,0.7141,0.7352,0.7357,0.7038,0.6777,0.6748,0.6873,0.6806,0.7225,0.7074,0.6095,
          0.6994,0.9406,0.8473,0.7650,0.7281,0.9262,0.8125,0.9033,0.7593,0.7500,0.6991,0.7973,0.6579,0.8723,0.8148,0.7667,0.7200,0.7054,0.7055,0.8611 ])


plt.show()
