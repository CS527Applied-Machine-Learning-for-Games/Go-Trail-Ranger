precision_list_aug = [0.6944444179534912, 0.7868020534515381, 0.9440000057220459, 0.75, 0.9047619104385376, 0.8373205661773682, 0.8434343338012695, 0.8269230723381042, 0.8097345232963562, 0.8757061958312988, 0.8051947951316833, 0.8797814249992371, 0.8018018007278442, 0.9366196990013123, 0.8520408272743225, 0.8791208863258362, 0.8870967626571655, 0.8302752375602722, 0.9197530746459961, 0.8398058414459229, 0.8235294222831726, 0.8522167205810547, 0.8542713522911072, 0.8791208863258362, 0.8617021441459656, 0.887005627155304, 0.8622449040412903]
recall_list_aug = [0.8838383555412292, 0.7828282713890076, 0.5959596037864685, 0.939393937587738, 0.7676767706871033, 0.8838383555412292, 0.8434343338012695, 0.868686854839325, 0.9242424368858337, 0.7828282713890076, 0.939393937587738, 0.8131313323974609, 0.8989899158477783, 0.6717171669006348, 0.8434343338012695, 0.808080792427063, 0.8333333134651184, 0.9141414165496826, 0.752525269985199, 0.8737373948097229, 0.9191918969154358, 0.8737373948097229, 0.8585858345031738, 0.808080792427063, 0.8181818127632141, 0.7929292917251587, 0.8535353541374207]
f1_score_list_aug = [0.7777777314186096, 0.7848101258277893, 0.7306501865386963, 0.834080696105957, 0.8306010961532593, 0.859950840473175, 0.8434343338012695, 0.847290575504303, 0.8632075786590576, 0.8266665935516357, 0.867132842540741, 0.8451443910598755, 0.8476190567016602, 0.7823529243469238, 0.8477157950401306, 0.8421052098274231, 0.8593749403953552, 0.870192289352417, 0.8277777433395386, 0.8564357161521912, 0.8687350749969482, 0.862842857837677, 0.8564230799674988, 0.8421052098274231, 0.8393782377243042, 0.8373332619667053, 0.8578680157661438]

a, b = len(val_loss_list), len(val_loss_list_aug)
epoch_list = list(range(0, max(a, b)))
if a < b:
  val_loss_list.extend([None] * (b - a))
  iteration_error_list.extend([None] * (b - a))
  val_accuracy_list.extend([None] * (b - a))
  precision_list.extend([None] * (b - a))
  recall_list.extend([None] * (b - a))
  f1_score_list.extend([None] * (b - a))
elif b < a:
  val_loss_list_aug.extend([None] * (a - b))
  iteration_error_list_aug.extend([None] * (a - b))
  val_accuracy_list_aug.extend([None] * (a - b))
  precision_list_aug.extend([None] * (a - b))
  recall_list_aug.extend([None] * (a - b))
  f1_score_list_aug.extend([None] * (a - b))

# %%
# Validation Loss
plt.title("ZSL - Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.plot(epoch_list, val_loss_list_aug, label="With Augmentation")
plt.plot(epoch_list, val_loss_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# Iteration Error
plt.title("ZSL - Iteration Error")
plt.xlabel("Epoch")
plt.ylabel("Iteration Error")
plt.plot(epoch_list, iteration_error_list_aug, label="With Augmentation")
plt.plot(epoch_list, iteration_error_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# Validation Accuracy
plt.title("ZSL - Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.plot(epoch_list, val_accuracy_list_aug, label="With Augmentation")
plt.plot(epoch_list, val_accuracy_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# Precision
plt.title("ZSL - Precision")
plt.xlabel("Epoch")
plt.ylabel("Precision")
plt.plot(epoch_list, precision_list_aug, label="With Augmentation")
plt.plot(epoch_list, precision_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# Recall
plt.title("ZSL - Recall")
plt.xlabel("Epoch")
plt.ylabel("Recall")
plt.plot(epoch_list, recall_list_aug, label="With Augmentation")
plt.plot(epoch_list, recall_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
recall_list_aug = [0.9852941036224365, 0.9558823704719543, 0.970588207244873, 0.9558823704719543, 0.9852941036224365, 0.9632353186607361, 0.9852941036224365, 0.845588207244873, 0.9558823704719543, 0.970588207244873, 0.9117646813392639, 0.9632353186607361, 0.845588207244873, 0.9411764740943909, 0.9558823704719543, 0.9779411554336548, 0.9852941036224365, 0.9338235259056091, 0.9485294222831726, 0.9338235259056091, 0.9338235259056091, 0.8602941036224365, 0.9411764740943909, 0.9338235259056091, 0.8970588445663452, 0.9779411554336548]
f1_score_list_aug = [0.9436619877815247, 0.9523809552192688, 0.9395017623901367, 0.9558823704719543, 0.9503545761108398, 0.9527273178100586, 0.9571428894996643, 0.9090909361839294, 0.9489051103591919, 0.95652174949646, 0.932330846786499, 0.9390681385993958, 0.9090909361839294, 0.9516728520393372, 0.9454545378684998, 0.9432623982429504, 0.9370629191398621, 0.9513108730316162, 0.9280576109886169, 0.9338235259056091, 0.937269389629364, 0.9176470637321472, 0.9481481313705444, 0.9407407641410828, 0.9242424368858337, 0.9300699234008789]


a, b = len(val_loss_list), len(val_loss_list_aug)
epoch_list = list(range(0, max(a, b)))
if a < b:
  val_loss_list.extend([None] * (b - a))
  iteration_error_list.extend([None] * (b - a))
  val_accuracy_list.extend([None] * (b - a))
  precision_list.extend([None] * (b - a))
  recall_list.extend([None] * (b - a))
  f1_score_list.extend([None] * (b - a))
elif b < a:
  val_loss_list_aug.extend([None] * (a - b))
  iteration_error_list_aug.extend([None] * (a - b))
  val_accuracy_list_aug.extend([None] * (a - b))
  precision_list_aug.extend([None] * (a - b))
  recall_list_aug.extend([None] * (a - b))
  f1_score_list_aug.extend([None] * (a - b))

# %%
# Validation Loss
plt.title("TL - Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.plot(epoch_list, val_loss_list_aug, label="With Augmentation")
plt.plot(epoch_list, val_loss_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# Iteration Error
plt.title("TL - Iteration Error")
plt.xlabel("Epoch")
plt.ylabel("Iteration Error")
plt.plot(epoch_list, iteration_error_list_aug, label="With Augmentation")
plt.plot(epoch_list, iteration_error_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# Validation Accuracy
plt.title("TL - Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.plot(epoch_list, val_accuracy_list_aug, label="With Augmentation")
plt.plot(epoch_list, val_accuracy_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# Precision
plt.title("TL - Precision")
plt.xlabel("Epoch")
plt.ylabel("Precision")
plt.plot(epoch_list, precision_list_aug, label="With Augmentation")
plt.plot(epoch_list, precision_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# Recall
plt.title("TL - Recall")
plt.xlabel("Epoch")
plt.ylabel("Recall")
plt.plot(epoch_list, recall_list_aug, label="With Augmentation")
plt.plot(epoch_list, recall_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# F1 Score
plt.title("TL - F1 Score")
plt.xlabel("Epoch")
plt.ylabel("F1 Score")
plt.plot(epoch_list, f1_score_list_aug, label="With Augmentation")
plt.plot(epoch_list, f1_score_list, label="Without Augmentation")
plt.legend()
plt.show()

# %% [markdown]
# ***Imitation Learning - Results***

# %%
# No Aug, Loss = 0.1854765536263585
val_loss_list = [0.5288810729980469, 0.21303872764110565, 0.17197883129119873, 0.19348248839378357, 0.18353919684886932, 0.21159759163856506, 0.2262851744890213, 0.20525026321411133, 0.2943172752857208, 0.19737187027931213, 0.25224393606185913, 0.27065351605415344, 0.228248730301857, 0.24977798759937286, 0.2661268413066864, 0.2562128007411957, 0.2723952531814575, 0.3845168650150299, 0.29622983932495117, 0.2445984184741974, 0.25608888268470764, 0.3549819886684418, 0.33402782678604126, 0.23271866142749786, 0.28568360209465027, 0.29998835921287537]
a, b = len(val_loss_list), len(val_loss_list_aug)
epoch_list = list(range(0, max(a, b)))
if a < b:
  val_loss_list.extend([None] * (b - a))
  iteration_error_list.extend([None] * (b - a))
  val_accuracy_list.extend([None] * (b - a))
  precision_list.extend([None] * (b - a))
  recall_list.extend([None] * (b - a))
  f1_score_list.extend([None] * (b - a))
elif b < a:
  val_loss_list_aug.extend([None] * (a - b))
  iteration_error_list_aug.extend([None] * (a - b))
  val_accuracy_list_aug.extend([None] * (a - b))
  precision_list_aug.extend([None] * (a - b))
  recall_list_aug.extend([None] * (a - b))
  f1_score_list_aug.extend([None] * (a - b))

# %%
# Validation Loss
plt.title("Imitation learning - Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.plot(epoch_list, val_loss_list_aug, label="With Augmentation")
plt.plot(epoch_list, val_loss_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# Iteration Error
plt.title("Imitation learning - Iteration Error")
plt.xlabel("Epoch")
plt.ylabel("Iteration Error")
plt.plot(epoch_list, iteration_error_list_aug, label="With Augmentation")
plt.plot(epoch_list, iteration_error_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# Validation Accuracy
plt.title("Imitation learning - Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.plot(epoch_list, val_accuracy_list_aug, label="With Augmentation")
plt.plot(epoch_list, val_accuracy_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# Precision
plt.title("Imitation learning - Precision")
plt.xlabel("Epoch")
plt.ylabel("Precision")
plt.plot(epoch_list, precision_list_aug, label="With Augmentation")
plt.plot(epoch_list, precision_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# Recall
plt.title("Imitation learning - Recall")
plt.xlabel("Epoch")
plt.ylabel("Recall")
plt.plot(epoch_list, recall_list_aug, label="With Augmentation")
plt.plot(epoch_list, recall_list, label="Without Augmentation")
plt.legend()
plt.show()

# %%
# F1 Score
plt.title("Imitation learning - F1 Score")
plt.xlabel("Epoch")
plt.ylabel("F1 Score")
plt.plot(epoch_list, f1_score_list_aug, label="With Augmentation")
plt.plot(epoch_list, f1_score_list, label="Without Augmentation")
plt.legend()
plt.show()

# %% [markdown]
# ***TL vs ZSL vs Imitation Learning***

# %%
# Without Aug Validation Loss

val_loss_list_zsl = [0.5081320405006409, 0.47756436467170715, 0.3504504859447479, 0.3544006049633026, 0.3548312783241272, 0.3751986622810364, 0.5601475834846497, 0.3490363359451294, 0.3892788589000702, 0.375408798456192, 0.3454940915107727, 0.41524919867515564, 0.41976282000541687, 0.4614368677139282, 0.5194616913795471, 0.4778643250465393, 0.49260860681533813, 0.4630573093891144, 0.47363102436065674, 0.7814831137657166, 0.6626798510551453, 0.5376144647598267, 0.46362295746803284, 0.5925853252410889, 0.6610912680625916, 0.6617709398269653, 0.4945722818374634, 0.5575318932533264, 0.6015986204147339, 0.6092931628227234, 0.7435427904129028, 0.682618260383606, 0.7550654411315918, 0.7127284407615662]

val_loss_list_tl = [0.4474004805088043, 0.23797698318958282, 0.14440828561782837, 0.1326454132795334, 0.15625089406967163, 0.14205260574817657, 0.15478447079658508, 0.15556198358535767, 0.194746732711792, 0.15706582367420197, 0.24509871006011963, 0.1722283959388733, 0.17891712486743927, 0.173087939620018, 0.23361144959926605, 0.17419826984405518, 0.1999601274728775, 0.19130998849868774, 0.21277166903018951, 0.20267298817634583, 0.22302988171577454, 0.2654804289340973, 0.2764710783958435, 0.2046983689069748, 0.21487705409526825, 0.2511846423149109, 0.2544502019882202]

val_loss_list_il = [0.5288810729980469, 0.21303872764110565, 0.17197883129119873, 0.19348248839378357, 0.18353919684886932, 0.21159759163856506, 0.2262851744890213, 0.20525026321411133, 0.2943172752857208, 0.19737187027931213, 0.25224393606185913, 0.27065351605415344, 0.228248730301857, 0.24977798759937286, 0.2661268413066864, 0.2562128007411957, 0.2723952531814575, 0.3845168650150299, 0.29622983932495117, 0.2445984184741974, 0.25608888268470764, 0.3549819886684418, 0.33402782678604126, 0.23271866142749786, 0.28568360209465027, 0.29998835921287537]

a, b, c = len(val_loss_list_zsl), len(val_loss_list_tl), len(val_loss_list_il)
size = max(a, b, c)
epoch_list = list(range(0, size))

val_loss_list_zsl.extend([None] * (size - a))
val_loss_list_tl.extend([None] * (size - b))
val_loss_list_il.extend([None] * (size - c))

# %%
# Validation Loss
plt.title("Imitation Learning vs ZSL vs TL - Validation Loss")
params = {'legend.fontsize': 3}
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.plot(epoch_list, val_loss_list_il, label="Imitation Learning")
plt.plot(epoch_list, val_loss_list_zsl, label="Zero Shot Learning")
plt.plot(epoch_list, val_loss_list_tl, label="Transfer Learning")
plt.legend()
plt.show()

# %%
# With Aug Validation Loss

val_loss_list_zsl = [0.6018684506416321, 0.3730873167514801, 0.4684002101421356, 0.40987157821655273, 0.3682710528373718, 0.3209890127182007, 0.3325745761394501, 0.3579733073711395, 0.36524271965026855, 0.39146196842193604, 0.44894176721572876, 0.3758646845817566, 0.4382052719593048, 0.5823553800582886, 0.4120258390903473, 0.4370691478252411, 0.4462747573852539, 0.48839786648750305, 0.5945223569869995, 0.4481126666069031, 0.40840578079223633, 0.45851749181747437, 0.5251409411430359, 0.5427664518356323, 0.5528988242149353, 0.5749437212944031, 0.502023458480835]

val_loss_list_tl = [0.4474004805088043, 0.23797698318958282, 0.14440828561782837, 0.1326454132795334, 0.15625089406967163, 0.14205260574817657, 0.15478447079658508, 0.15556198358535767, 0.194746732711792, 0.15706582367420197, 0.24509871006011963, 0.1722283959388733, 0.17891712486743927, 0.173087939620018, 0.23361144959926605, 0.17419826984405518, 0.1999601274728775, 0.19130998849868774, 0.21277166903018951, 0.20267298817634583, 0.22302988171577454, 0.2654804289340973, 0.2764710783958435, 0.2046983689069748, 0.21487705409526825, 0.2511846423149109, 0.2544502019882202]

val_loss_list_il = [0.1546904295682907, 0.13690592348575592, 0.13769705593585968, 0.12207461148500443, 0.15320952236652374, 0.13460685312747955, 0.14690251648426056, 0.19803987443447113, 0.14636199176311493, 0.1407332569360733, 0.1736120581626892, 0.14518007636070251, 0.25043660402297974, 0.15311716496944427, 0.16344133019447327, 0.18701548874378204, 0.2621297538280487, 0.18442502617835999, 0.19388292729854584, 0.20074543356895447, 0.18233957886695862, 0.22780464589595795, 0.18021515011787415, 0.19025850296020508, 0.2509104907512665, 0.24195793271064758]

a, b, c = len(val_loss_list_zsl), len(val_loss_list_tl), len(val_loss_list_il)
size = max(a, b, c)
epoch_list = list(range(0, size))

val_loss_list_zsl.extend([None] * (size - a))
val_loss_list_tl.extend([None] * (size - b))
val_loss_list_il.extend([None] * (size - c))

# %%
# Validation Loss
plt.title("Imitation Learning vs ZSL vs TL - Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.plot(epoch_list, val_loss_list_il, label="Imitation Learning")
plt.plot(epoch_list, val_loss_list_zsl, label="Zero Shot Learning")
plt.plot(epoch_list, val_loss_list_tl, label="Transfer Learning")
plt.legend()
plt.show()

# %%
# ACCURACY

val_loss_list_zsl = [0.7487437129020691, 0.7964823842048645, 0.8216080069541931, 0.839195966720581, 0.8417085409164429, 0.8366833925247192, 0.7814069986343384, 0.8366833925247192, 0.8542713522911072, 0.8492462038993835, 0.856783926486969, 0.8366833925247192, 0.856783926486969, 0.8643215894699097, 0.8467336297035217, 0.8517587780952454, 0.8668341636657715, 0.8492462038993835, 0.8592965006828308, 0.8165829181671143, 0.8517587780952454, 0.856783926486969, 0.8668341636657715, 0.8668341636657715, 0.876884400844574, 0.8592965006828308, 0.8492462038993835, 0.8542713522911072, 0.8643215894699097, 0.8718593120574951, 0.856783926486969, 0.8668341636657715, 0.856783926486969, 0.8592965006828308]

val_loss_list_il = [0.6279069781303406, 0.9003322124481201, 0.9335547685623169, 0.9235880374908447, 0.9003322124481201, 0.9501661062240601, 0.9435215592384338, 0.9335547685623169, 0.9368770718574524, 0.9335547685623169, 0.9036544561386108, 0.9235880374908447, 0.9401993155479431, 0.9435215592384338, 0.9269102811813354, 0.9368770718574524, 0.9169434905052185, 0.9335547685623169, 0.8903654217720032, 0.9202657341957092, 0.9335547685623169, 0.9368770718574524, 0.8970099687576294, 0.9235880374908447, 0.9468438029289246, 0.9401993155479431, 0.9435215592384338]

val_loss_list_tl = [0.9468438029289246, 0.9568105936050415, 0.9435215592384338, 0.960132896900177, 0.9534883499145508, 0.9568105936050415, 0.960132896900177, 0.9235880374908447, 0.9534883499145508, 0.960132896900177, 0.9401993155479431, 0.9435215592384338, 0.9235880374908447, 0.9568105936050415, 0.9501661062240601, 0.9468438029289246, 0.9401993155479431, 0.9568105936050415, 0.9335547685623169, 0.9401993155479431, 0.9435215592384338, 0.9302325248718262, 0.9534883499145508, 0.9468438029289246, 0.9335547685623169, 0.9335547685623169]

a, b, c = len(val_loss_list_zsl), len(val_loss_list_tl), len(val_loss_list_il)
size = max(a, b, c)
epoch_list = list(range(0, size))

val_loss_list_zsl.extend([None] * (size - a))
val_loss_list_tl.extend([None] * (size - b))
val_loss_list_il.extend([None] * (size - c))

# %%
# Validation Loss
plt.title("Imitation Learning vs ZSL vs TL - Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.plot(epoch_list, val_loss_list_il, label="Imitation Learning")
plt.plot(epoch_list, val_loss_list_zsl, label="Zero Shot Learning")
plt.plot(epoch_list, val_loss_list_tl, label="Transfer Learning")
plt.legend()
plt.show()
